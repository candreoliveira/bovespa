# %%
import bovespa
import pandas as pd
import csv
import fnmatch
import re
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from os import listdir, path
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
class Indicator:
    @classmethod
    def netincome(self, df, price_attr, date_attr, **kwargs):
        buy_date = (kwargs.get("buy_date") or df[date_attr][0])
        sell_date = (kwargs.get("sell_date") or df[date_attr][df[date_attr].size - 1])
        Netincome = pd.Series(None, index = df.index, name = (kwargs.get("netincome_value_name") or "NETINCOME_VALUE"))
        Netincome_percent = pd.Series(None, index = df.index, name = (kwargs.get("netincome_percent_name") or "NETINCOME_PERCENT"))
        
        for idx, value in df.iterrows():
            if value[date_attr] > buy_date and value[date_attr] <= sell_date:
                Netincome[idx] = value[price_attr] - df[df[date_attr] == buy_date][price_attr]
                Netincome_percent[idx] = Netincome[idx] * 100 / df[df[date_attr] == buy_date][price_attr]
                
        return pd.concat([Netincome, Netincome_percent], join='outer', axis=1)
    
    @classmethod
    def netincome_with_ratio(self, df, stock1_price_attr, stock2_price_attr, date_attr, bb_ratio_attr, bb_base_attr, bb_trend_attr, **kwargs):
        buy_date = (kwargs.get("buy_date") or df[date_attr][0])
        sell_date = (kwargs.get("sell_date") or df[date_attr][df[date_attr].size - 1])
        Netincome = pd.Series(None, index = df.index, name = (kwargs.get("netincome_value_name") or "NETINCOME_RATIO_VALUE"))
        Netincome_percent = pd.Series(None, index = df.index, name = (kwargs.get("netincome_percent_name") or "NETINCOME_RATIO_PERCENT"))
        
        # It defines the first buy of stock for net income calculation
        last_date = buy_date
        last_trend = 1 if df[df[date_attr] == last_date][bb_ratio_attr] > df[df[date_attr] == last_date][bb_base_attr] else -1
        last_price = stock1_price_attr if last_trend == -1 else stock2_price_attr
        
        for idx, value in df.iterrows():
            if value[date_attr] > buy_date and value[date_attr] <= sell_date:                
                Netincome[idx] = value[last_price] - df[df[date_attr] == last_date][last_price]
                Netincome_percent[idx] = Netincome[idx] * 100 / df[df[date_attr] == buy_date][price_attr]
                
                # Buy stock 2 and sell stock 1
                if value[bb_trend_attr] == 1 and last_trend == -1:
                    last_trend = 1
                elif value[bb_trend_attr] == -1 and last_trend == 1:
                    last_trend = -1
                else:
                    

                
        return pd.concat([Netincome, Netincome_percent], join='outer', axis=1)    
            
    @classmethod
    def bbands(self, df, price_attr, n, nstd, nresult, **kwargs):
        MA = pd.Series(df[price_attr].rolling(window=n).mean())
        MSD = pd.Series(df[price_attr].rolling(window=n).std())
        
        Base = pd.Series(MA, name = (kwargs.get("base_name") or "BASE"))
        Middle_upper = pd.Series(MA + MSD * nstd/2, name = (kwargs.get("middle_upper_name") or "MIDDLE_UPPER"))
        Middle_lower = pd.Series(MA - MSD * nstd/2, name = (kwargs.get("middle_lower_name") or "MIDDLE_LOWER"))
        Upper = pd.Series(MA + MSD * nstd, name = (kwargs.get("upper_name") or "UPPER"))
        Lower = pd.Series(MA - MSD * nstd, name = (kwargs.get("lower_name") or "LOWER"))        
        
        Trend = pd.Series(0, index = Lower.index, name = (kwargs.get("trend_name") or "TREND"))
        Result = pd.Series(None, index = Lower.index, name = (kwargs.get("result_name") or "RESULT"))
        
        last_result = None
        last_idx = None
        last_trend = None
        
        for idx, value in Upper.iteritems():
            if idx >= n:
                # Trend/Result calculation
                if ((last_trend != 1) and ((df[price_attr][idx] > Upper[idx]) or 
                    ((last_trend == -1) and ((idx - last_idx) >= nresult) and (df[price_attr][idx] > Middle_upper[idx])) or
                    ((last_trend == -1) and ((idx - last_idx) >= 2*nresult) and (df[price_attr][idx] > Base[idx])))):
                    Trend[idx] = 1   
                elif ((last_trend != -1) and ((df[price_attr][idx] < Lower[idx]) or 
                      ((last_trend == 1) and ((idx - last_idx) >= nresult) and (df[price_attr][idx] < Middle_lower[idx])) or
                      ((last_trend == 1) and ((idx - last_idx) >= 2*nresult) and (df[price_attr][idx] < Base[idx])))):
                    Trend[idx] = -1                                   
                    
                # Lower/Upper adjust based on trend    
                if (Trend[idx] == 1) and (Lower[idx] < Lower[idx-1]):
                    Lower[idx] = Lower[idx-1]
                elif (Trend[idx] == -1) and (Upper[idx] > Upper[idx-1]):
                    Upper[idx] = Upper[idx-1]
                
                # Update result
                if (Trend[idx] != 0):
                    Result[idx] = df[price_attr][idx]
                    last_result = Result[idx]
                    last_idx = idx
                    last_trend = Trend[idx]                    
                    
        return pd.concat([Upper, Middle_upper, Base, Middle_lower, Lower, Result, Trend], join='outer', axis=1)

class Parser:
    def __init__(self, inpt, output=None):
        self.input = inpt
        self.output = output

    @classmethod
    def convert_record_to_dict(self, query):
        for rec in query:
            yield rec.info

    def get_query(self):
        bf = bovespa.File(self.input)
        return bf.query()

    def get_dataframe(self):
        return pd.DataFrame(self.convert_record_to_dict(self.get_query()))
    
class Select:
    def __init__(self, option=None, dropdown=None):
        self.option = option
        self.dropdown = dropdown
        
    def get_dropdown(self, options, description="Option:"):
        if not self.dropdown:
            w = widgets.Dropdown(options=options,description=description,value=options[0])
            w.observe(self.on_change)
            self.dropdown = w
            self.option = w.value
        
        return self.dropdown
    
    def on_change(self, change):      
        if change.name == "value" and change.type == "change":
            self.option = change.new    
            
class Reader(Select):
    @classmethod
    def get_files(self, where, regex):
        return [name for name in listdir(where) if re.compile(fnmatch.translate(regex), re.IGNORECASE).match(name)]

# %%
directory = "../data"
file = Select()
display(file.get_dropdown(Reader.get_files(directory, "*.txt"), "Arquivo:"))
# Out:
# Dropdown(description='Arquivo:', options=('COTAHIST_A2017.TXT',), value='COTAHIST_A2017.TXT')

# %%
p = Parser(path.join(directory, file.option))
d = p.get_dataframe()
codes = d.CODNEG

# %%
options = codes[
    np.logical_and(
        ~codes.str.contains("\d\w|\d\d"),
        codes.str.contains("\d")
    )].sort_values().unique()

stock1 = Select()
stock2 = Select()

display(stock1.get_dropdown(options, "Stock 1:"))
display(stock2.get_dropdown(options, "Stock 2:"))
# Out:
# Dropdown(description='Stock 1:', options=('AALR3', 'ABCB2', 'ABCB4', 'ABEV3', 'ABEVA1', 'ABEVA3', 'ABEVA7', 'A…
# Dropdown(description='Stock 2:', options=('AALR3', 'ABCB2', 'ABCB4', 'ABEV3', 'ABEVA1', 'ABEVA3', 'ABEVA7', 'A…

# %%
d_stock1 = d[codes == stock1.option]
d_stock1.index = range(len(d_stock1))
d_stock2 = d[codes == stock2.option]
d_stock2.index = range(len(d_stock2))

formula = f'{stock1.option}/{stock2.option}'

df = pd.DataFrame()
df['DATE'] = d_stock1.DATPRG
df['FORMULA'] = formula
df['RATIO'] = d_stock1.PREULT/d_stock2.PREULT
df[stock1.option] = d_stock1.PREULT
df[stock2.option] = d_stock2.PREULT

bbands = Indicator.bbands(
    df, "RATIO", 21, 2, 15,
    upper_name="BBANDS_UPPER",
    middle_upper_name="BBANDS_MIDDLEUPPER",
    base_name="BBANDS_BASE",
    middle_lower_name="BBANDS_MIDDLELOWER",    
    lower_name="BBANDS_LOWER",
    trend_name="BBANDS_TREND",
    result_name="BBANDS_RESULT"
)

netincome_stock1 = Indicator.netincome(
    df, 
    stock1.option, 
    "DATE",
    buy_date = buy_date.option, 
    sell_date = sell_date.option,     
    netincome_value_name = ("NETINCOME_VALUE_" + stock1.option), 
    netincome_percent_name = ("NETINCOME_PERCENT_" + stock1.option)
)

netincome_stock2 = Indicator.netincome(
    df, 
    stock2.option, 
    "DATE", 
    buy_date = buy_date.option, 
    sell_date = sell_date.option, 
    netincome_value_name = ("NETINCOME_VALUE_" + stock2.option), 
    netincome_percent_name = ("NETINCOME_PERCENT_" + stock2.option)
)

df = pd.merge(df, bbands, left_index=True, right_index=True)
df = pd.merge(df, netincome_stock1, left_index=True, right_index=True)
df = pd.merge(df, netincome_stock2, left_index=True, right_index=True)

buy_date = Select()
sell_date = Select()

display(buy_date.get_dropdown(df.DATE, "Buy Date:"))
display(sell_date.get_dropdown(df.DATE, "Sell Date:"))
# Out:
# Dropdown(description='Buy Date:', options=(datetime.date(2017, 1, 2), datetime.date(2017, 1, 3), datetime.date…
# Dropdown(description='Sell Date:', options=(datetime.date(2017, 1, 2), datetime.date(2017, 1, 3), datetime.dat…

# %%
fig, ax = plt.subplots()
ax.plot(df["DATE"], df[stock1.option], marker='o', markersize=2, color='green')
ax.plot(df["DATE"], df[stock2.option], marker='o', markersize=2, color='blue')

fig.set_size_inches(30,10)

ax.set_xlabel("DATE", size=18)
ax.set_ylabel("PRICE", size=18)
ax.set_autoscale_on(True)
ax.set_title("Price Analysis: " + stock1.option + " e " + stock2.option, size=26)
ax.tick_params(labelsize="large")
ax.grid()
ax.legend(fontsize='x-large')

# fig.savefig("test.png")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df["DATE"], df['BBANDS_UPPER'], marker='o', markersize=2, color='green', label='Band Upper')
ax.plot(df["DATE"], df['BBANDS_MIDDLEUPPER'], marker='o', markersize=2, ls='solid', color='turquoise', label='Band Middle Upper')
ax.plot(df["DATE"], df['BBANDS_BASE'], marker='o', markersize=2, color='silver', label='Band Base')
ax.plot(df["DATE"], df['BBANDS_MIDDLELOWER'], marker='o', markersize=2, ls='solid', color='orchid', label='Band Middle Lower')
ax.plot(df["DATE"], df['BBANDS_LOWER'], marker='o', markersize=2, color='purple', label='Band Lower')
ax.plot(df["DATE"], df['RATIO'], marker='o', markersize=2, color='blue', label='Ratio')
ax.plot(df["DATE"], df['BBANDS_RESULT'], marker='x', ls='None', ms=20, mec='r', mew=3, color='r', label='Operation')

fig.set_size_inches(30,10)

ax.set_xlabel("DATE", size=18)
ax.set_ylabel("RATIO", size=18)
ax.set_autoscale_on(True)
ax.set_title("Ratio Analysis: " + formula, size=26)
ax.tick_params(labelsize="large")
ax.grid()
ax.legend(fontsize='x-large')

# fig.savefig("test.png")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df["DATE"], df[('NETINCOME_PERCENT_' + stock1.option)], marker='o', markersize=2, color='green', label= (stock1.option + ' Net Income Percent'))
ax.plot(df["DATE"], df[('NETINCOME_PERCENT_' + stock2.option)], marker='o', markersize=2, color='blue', label=(stock1.option + ' Net Income Percent'))

fig.set_size_inches(30,10)

ax.set_xlabel("DATE", size=18)
ax.set_ylabel("NET INCOME (%)", size=18)
ax.set_autoscale_on(True)
ax.set_title("Net Income Percent Analysis: " + stock1.option + " e " + stock2.option, size=26)
ax.tick_params(labelsize="large")
ax.grid()
ax.legend(fontsize='x-large')

# fig.savefig("test.png")
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(df["DATE"], df[('NETINCOME_VALUE_' + stock1.option)], marker='o', markersize=2, color='green', label= (stock1.option + ' Net Income'))
ax.plot(df["DATE"], df[('NETINCOME_VALUE_' + stock2.option)], marker='o', markersize=2, color='blue', label=(stock1.option + ' Net Income'))

fig.set_size_inches(30,10)

ax.set_xlabel("DATE", size=18)
ax.set_ylabel("NET INCOME (R$)", size=18)
ax.set_autoscale_on(True)
ax.set_title("Net Income Analysis: " + stock1.option + " e " + stock2.option, size=26)
ax.tick_params(labelsize="large")
ax.grid()
ax.legend(fontsize='x-large')

# fig.savefig("test.png")
plt.show()

# %%
# a = df.DATE[1]
# b = df.DATE[4]
# df[(df.DATE > a) & (df.DATE < b)]

# Indicator.netincome(df, stock1.option, "DATE")
